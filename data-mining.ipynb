# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/Dataset-Unicauca-Version2-87Atts.csv')
df.sample(10)
# Out:
#                                          Flow.ID       Source.IP  Source.Port  \
# 2860363  216.58.222.206-10.200.7.194-443-40125-6    10.200.7.194        40125
# 3496983     179.1.4.244-10.200.7.217-443-36996-6    10.200.7.217        36996
# 3490793     10.200.7.217-69.164.26.26-41446-80-6    10.200.7.217        41446
# 1782854   10.200.7.218-74.119.117.72-37529-443-6    10.200.7.218        37529
# 1378665    192.168.142.32-10.200.7.9-2075-3128-6      10.200.7.9         3128
# 2103706       10.200.7.6-10.230.1.3-3128-50478-6      10.230.1.3        50478
# 730256   209.85.224.156-10.200.7.195-443-36973-6    10.200.7.195        36973
# 2184739      179.1.4.231-10.200.7.196-80-48953-6    10.200.7.196        48953
# 273803    192.168.60.127-10.200.7.7-63941-3128-6  192.168.60.127        63941
# 2614427   192.168.72.103-10.200.7.5-50870-3128-6      10.200.7.5         3128
#
#          Destination.IP  Destination.Port  Protocol           Timestamp  \
# ...

# %%
df.columns
# Out:
# Index(['Flow.ID', 'Source.IP', 'Source.Port', 'Destination.IP',
#        'Destination.Port', 'Protocol', 'Timestamp', 'Flow.Duration',
#        'Total.Fwd.Packets', 'Total.Backward.Packets',
#        'Total.Length.of.Fwd.Packets', 'Total.Length.of.Bwd.Packets',
#        'Fwd.Packet.Length.Max', 'Fwd.Packet.Length.Min',
#        'Fwd.Packet.Length.Mean', 'Fwd.Packet.Length.Std',
#        'Bwd.Packet.Length.Max', 'Bwd.Packet.Length.Min',
#        'Bwd.Packet.Length.Mean', 'Bwd.Packet.Length.Std', 'Flow.Bytes.s',
#        'Flow.Packets.s', 'Flow.IAT.Mean', 'Flow.IAT.Std', 'Flow.IAT.Max',
#        'Flow.IAT.Min', 'Fwd.IAT.Total', 'Fwd.IAT.Mean', 'Fwd.IAT.Std',
#        'Fwd.IAT.Max', 'Fwd.IAT.Min', 'Bwd.IAT.Total', 'Bwd.IAT.Mean',
#        'Bwd.IAT.Std', 'Bwd.IAT.Max', 'Bwd.IAT.Min', 'Fwd.PSH.Flags',
#        'Bwd.PSH.Flags', 'Fwd.URG.Flags', 'Bwd.URG.Flags', 'Fwd.Header.Length',
#        'Bwd.Header.Length', 'Fwd.Packets.s', 'Bwd.Packets.s',
# ...

# %%
df1 = df[['Flow.Duration',
       'Total.Fwd.Packets', 'Total.Backward.Packets',
       'Total.Length.of.Fwd.Packets', 'Total.Length.of.Bwd.Packets',
       'Fwd.Packet.Length.Max', 'Fwd.Packet.Length.Min',
       'Fwd.Packet.Length.Mean', 'Fwd.Packet.Length.Std',
       'Bwd.Packet.Length.Max', 'Bwd.Packet.Length.Min',
       'Bwd.Packet.Length.Mean', 'Bwd.Packet.Length.Std', 'Flow.Bytes.s',
       'Flow.Packets.s', 'Flow.IAT.Mean', 'Flow.IAT.Std', 'Flow.IAT.Max',
       'Flow.IAT.Min', 'Fwd.IAT.Total', 'Fwd.IAT.Mean', 'Fwd.IAT.Std',
       'Fwd.IAT.Max', 'Fwd.IAT.Min', 'Bwd.IAT.Total', 'Bwd.IAT.Mean',
       'Bwd.IAT.Std', 'Bwd.IAT.Max', 'Bwd.IAT.Min','Fwd.Header.Length',
       'Bwd.Header.Length', 'Fwd.Packets.s', 'Bwd.Packets.s',
       'Min.Packet.Length', 'Max.Packet.Length', 'Packet.Length.Mean',
       'Packet.Length.Std', 'Packet.Length.Variance','Down.Up.Ratio',
       'Average.Packet.Size', 'Avg.Fwd.Segment.Size', 'Avg.Bwd.Segment.Size',
       'Fwd.Avg.Bytes.Bulk', 'Fwd.Avg.Packets.Bulk',
       'Fwd.Avg.Bulk.Rate', 'Bwd.Avg.Bytes.Bulk', 'Bwd.Avg.Packets.Bulk',
       'Bwd.Avg.Bulk.Rate']]

# %%
df1.head()
# Out:
#    Flow.Duration  Total.Fwd.Packets  Total.Backward.Packets  \
# 0          45523                 22                      55
# 1              1                  2                       0
# 2              1                  3                       0
# 3            217                  1                       3
# 4          78068                  5                       0
#
#    Total.Length.of.Fwd.Packets  Total.Length.of.Bwd.Packets  \
# 0                          132                     110414.0
# 1                           12                          0.0
# 2                          674                          0.0
# 3                            0                          0.0
# 4                         1076                          0.0
#
#    Fwd.Packet.Length.Max  Fwd.Packet.Length.Min  Fwd.Packet.Length.Mean  \
# 0                      6                      6                6.000000
# 1                      6                      6                6.000000
# ...

# %%
webservices = list(set(list(df['ProtocolName'].values)))
webservices
# Out:
# ['HTTP_CONNECT',
#  'RADIUS',
#  'GOOGLE_MAPS',
#  'LASTFM',
#  'CNN',
#  'DROPBOX',
#  'LOTUS_NOTES',
#  'FTP_CONTROL',
#  'HTTP_PROXY',
#  'OPENVPN',
#  'SSL',
#  'QQ',
#  'BGP',
#  'CITRIX',
#  'MSN',
#  'OFFICE_365',
#  'HTTP_DOWNLOAD',
#  'TWITTER',
#  'TIMMEU',
#  'DEEZER',
#  'NFS',
#  'TELEGRAM',
#  'SKINNY',
#  'TEAMVIEWER',
#  'SNMP',
#  'GOOGLE',
#  'APPLE',
#  'NTP',
#  'STARCRAFT',
#  'NETFLIX',
#  'INSTAGRAM',
#  'UBUNTUONE',
#  'UPNP',
#  'MSSQL',
#  'WAZE',
#  'MAIL_IMAPS',
#  'SIMET',
#  'MQTT',
#  'AMAZON',
#  'WHOIS_DAS',
#  'GMAIL',
#  'EDONKEY',
#  'BITTORRENT',
#  'WHATSAPP',
#  'YOUTUBE',
#  'SPOTIFY',
#  'TWITCH',
#  '99TAXI',
#  'APPLE_ITUNES',
#  'TOR',
#  'DNS',
#  'CONTENT_FLASH',
#  'HTTP',
#  'FTP_DATA',
#  'WIKIPEDIA',
#  'FACEBOOK',
#  'SOCKS',
#  'CLOUDFLARE',
#  'ORACLE',
#  'CITRIX_ONLINE',
#  'APPLE_ICLOUD',
#  'MICROSOFT',
#  'YAHOO',
#  'OPENSIGNAL',
#  'SSL_NO_CERT',
#  'RTMP',
#  'TEAMSPEAK',
#  'SKYPE',
#  'IP_ICMP',
#  'UNENCRYPED_JABBER',
# ...

# %%
# !pip install sklearn
# Out:
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=a6ec819df54714c72eb449d0ee923e4d615572755dcd7e92b7cc32d9de84968d
#   Stored in directory: c:\users\arjun\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
X = StandardScaler().fit_transform(df1)
X
# Out:
# array([[-0.6326414 , -0.03690568, -0.0093321 , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.63377536, -0.05518578, -0.05896696, ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.63377536, -0.05427178, -0.05896696, ...,  0.        ,
#          0.        ,  0.        ],
#        ...,
#        [-0.56921694, -0.05152976, -0.0544547 , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.56845051, -0.05335777, -0.0562596 , ...,  0.        ,
#          0.        ,  0.        ],
#        [-0.58372747, -0.05427178, -0.05716205, ...,  0.        ,
#          0.        ,  0.        ]])

# %%
clustered = KMeans(n_clusters=len(webservices)).fit_transform(X)
clustered
